# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import glob
import csv
from scipy import stats

# %%
file= open(r"C:\Users\Kelvin\source\repos\Module5Challenge\Study_results.csv")
with open(r"C:\Users\Kelvin\source\repos\Module5Challenge\Study_results.csv") as file:
 csvreader_studyr = csv.reader(file)
 studyreport = pd.DataFrame(csvreader_studyr)


file2= open(r"C:\Users\Kelvin\source\repos\Module5Challenge\Mouse_metadata.csv")
with open(r"C:\Users\Kelvin\source\repos\Module5Challenge\Mouse_metadata.csv") as file:
 csvreader_mouse = csv.reader(file2)
 mouse = pd.DataFrame(csvreader_mouse)
 
 print(mouse)
 print(studyreport)
# Out:
#             0             1       2           3           4
# 0    Mouse ID  Drug Regimen     Sex  Age_months  Weight (g)
# 1        k403      Ramicane    Male          21          16
# 2        s185     Capomulin  Female           3          17
# 3        x401     Capomulin  Female          16          15
# 4        m601     Capomulin    Male          22          17
# ..        ...           ...     ...         ...         ...
# 245      z314      Stelasyn  Female          21          28
# 246      z435      Propriva  Female          12          26
# 247      z581     Infubinol  Female          24          25
# 248      z795      Naftisol  Female          13          29
# 249      z969      Naftisol    Male           9          30
#
# [250 rows x 5 columns]
#              0          1                   2                 3
# 0     Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 1         b128          0                  45                 0
# 2         f932          0                  45                 0
# 3         g107          0                  45                 0
# 4         a457          0                  45                 0
# ...        ...        ...                 ...               ...
# 1889      r944         45         41.58152074                 2
# 1890      u364         45         31.02392294                 3
# 1891      p438         45         61.43389223                 1
# 1892      x773         45         58.63497149                 4
# 1893      b879         45         72.55523894                 2
#
# [1894 rows x 4 columns]

# %%
left = pd.DataFrame(mouse)

left.columns = left.iloc[0]
left = left[1:]

print(left)
# Out:
# 0   Mouse ID Drug Regimen     Sex Age_months Weight (g)
# 1       k403     Ramicane    Male         21         16
# 2       s185    Capomulin  Female          3         17
# 3       x401    Capomulin  Female         16         15
# 4       m601    Capomulin    Male         22         17
# 5       g791     Ramicane    Male         11         16
# ..       ...          ...     ...        ...        ...
# 245     z314     Stelasyn  Female         21         28
# 246     z435     Propriva  Female         12         26
# 247     z581    Infubinol  Female         24         25
# 248     z795     Naftisol  Female         13         29
# 249     z969     Naftisol    Male          9         30
#
# [249 rows x 5 columns]

# %%
studyrepot = pd.DataFrame(studyreport)

studyrepot.columns = studyrepot.iloc[0]
studyrepot = studyrepot[1:]

print(studyrepot)
# Out:
# 0    Mouse ID Timepoint Tumor Volume (mm3) Metastatic Sites
# 1        b128         0                 45                0
# 2        f932         0                 45                0
# 3        g107         0                 45                0
# 4        a457         0                 45                0
# 5        c819         0                 45                0
# ...       ...       ...                ...              ...
# 1889     r944        45        41.58152074                2
# 1890     u364        45        31.02392294                3
# 1891     p438        45        61.43389223                1
# 1892     x773        45        58.63497149                4
# 1893     b879        45        72.55523894                2
#
# [1893 rows x 4 columns]

# %%
csv_files = glob.glob('*.{}'.format('csv'))
print(csv_files)
# Out:
# ['Mouse_metadata.csv', 'Study_results.csv']

# %%
df_csv_concat = pd.DataFrame()

 
df_csv_concat = pd.concat([pd.read_csv(file) for file in csv_files ], ignore_index=True)
print(df_csv_concat)
# Out:
#      Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane    Male        21.0        16.0        NaN
# 1        s185    Capomulin  Female         3.0        17.0        NaN
# 2        x401    Capomulin  Female        16.0        15.0        NaN
# 3        m601    Capomulin    Male        22.0        17.0        NaN
# 4        g791     Ramicane    Male        11.0        16.0        NaN
# ...       ...          ...     ...         ...         ...        ...
# 2137     r944          NaN     NaN         NaN         NaN       45.0
# 2138     u364          NaN     NaN         NaN         NaN       45.0
# 2139     p438          NaN     NaN         NaN         NaN       45.0
# 2140     x773          NaN     NaN         NaN         NaN       45.0
# 2141     b879          NaN     NaN         NaN         NaN       45.0
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0                    NaN               NaN
# 1                    NaN               NaN
# 2                    NaN               NaN
# 3                    NaN               NaN
# 4                    NaN               NaN
# ...                  ...               ...
# 2137           41.581521               2.0
# 2138           31.023923               3.0
# 2139           61.433892               1.0
# 2140           58.634971               4.0
# 2141           72.555239               2.0
#
# [2142 rows x 8 columns]

# %%
right = pd.DataFrame(studyrepot)
right = studyrepot[studyrepot["Timepoint"] == str(45)]
print(right)
x=len(right)
print(x)
# Out:
# 0    Mouse ID Timepoint Tumor Volume (mm3) Metastatic Sites
# 1764     n364        45        31.09533505                1
# 1765     b128        45        38.98287774                2
# 1766     l661        45        59.85195552                3
# 1767     y865        45        64.72983655                3
# 1768     y769        45        68.59474498                4
# ...       ...       ...                ...              ...
# 1889     r944        45        41.58152074                2
# 1890     u364        45        31.02392294                3
# 1891     p438        45        61.43389223                1
# 1892     x773        45        58.63497149                4
# 1893     b879        45        72.55523894                2
#
# [130 rows x 4 columns]
# 130

# %%
df_csv_concat = pd.DataFrame()

# %%
df_csv_concat = pd.concat([pd.read_csv(file) for file in csv_files ], ignore_index=True)
print(df_csv_concat)
# Out:
#      Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane    Male        21.0        16.0        NaN
# 1        s185    Capomulin  Female         3.0        17.0        NaN
# 2        x401    Capomulin  Female        16.0        15.0        NaN
# 3        m601    Capomulin    Male        22.0        17.0        NaN
# 4        g791     Ramicane    Male        11.0        16.0        NaN
# ...       ...          ...     ...         ...         ...        ...
# 2137     r944          NaN     NaN         NaN         NaN       45.0
# 2138     u364          NaN     NaN         NaN         NaN       45.0
# 2139     p438          NaN     NaN         NaN         NaN       45.0
# 2140     x773          NaN     NaN         NaN         NaN       45.0
# 2141     b879          NaN     NaN         NaN         NaN       45.0
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0                    NaN               NaN
# 1                    NaN               NaN
# 2                    NaN               NaN
# 3                    NaN               NaN
# 4                    NaN               NaN
# ...                  ...               ...
# 2137           41.581521               2.0
# 2138           31.023923               3.0
# 2139           61.433892               1.0
# 2140           58.634971               4.0
# 2141           72.555239               2.0
#
# [2142 rows x 8 columns]

# %%
clean_df_csv_concat = pd.DataFrame(df_csv_concat)

clean_df_csv_concat = pd.merge(left, right, left_on ="Mouse ID", right_on = "Mouse ID" , how='inner')
print(clean_df_csv_concat)
# Out:
# 0   Mouse ID Drug Regimen     Sex Age_months Weight (g) Timepoint  \
# 0       k403     Ramicane    Male         21         16        45
# 1       s185    Capomulin  Female          3         17        45
# 2       x401    Capomulin  Female         16         15        45
# 3       m601    Capomulin    Male         22         17        45
# 4       g791     Ramicane    Male         11         16        45
# ..       ...          ...     ...        ...        ...       ...
# 125     y769     Ceftamin  Female          6         27        45
# 126     y865     Ceftamin    Male         23         26        45
# 127     z581    Infubinol  Female         24         25        45
# 128     z795     Naftisol  Female         13         29        45
# 129     z969     Naftisol    Male          9         30        45
#
# 0   Tumor Volume (mm3) Metastatic Sites
# 0          22.05012627                1
# 1          23.34359787                1
# 2          28.48403281                0
# 3          28.43096411                1
# 4          29.12847181                1
# ..                 ...              ...
# 125        68.59474498                4
# 126        64.72983655                3
# 127        62.75445141                3
# 128        65.74107029                3
# 129        73.86784476                4
#
# [130 rows x 8 columns]

# %%
clean_df_csv_concat['Tumor Volume (mm3)'] = pd.to_numeric(clean_df_csv_concat['Tumor Volume (mm3)'])

# %%
mean = clean_df_csv_concat.groupby("Drug Regimen")["Tumor Volume (mm3)"].mean()
median = clean_df_csv_concat.groupby("Drug Regimen")["Tumor Volume (mm3)"].median()
variance = clean_df_csv_concat.groupby("Drug Regimen")["Tumor Volume (mm3)"].var()
sd = clean_df_csv_concat.groupby("Drug Regimen")["Tumor Volume (mm3)"].std()

n_samples = len(right)
sem = sd / np.sqrt(n_samples)

# %%
statistics = pd.DataFrame({"Mean": mean,
                           "Median": median,
                           "Variance": variance,
                           "SD": sd,
                           "SEM": sem})

print(statistics)
# Out:
#                    Mean     Median   Variance        SD       SEM
# Drug Regimen
# Capomulin     36.236114  37.311846  31.460537  5.608969  0.491939
# Ceftamin      64.132421  64.299830  10.585242  3.253497  0.285351
# Infubinol     65.755562  66.083066  11.787426  3.433282  0.301119
# Ketapril      70.662958  69.872251  23.229260  4.819674  0.422713
# Naftisol      69.265506  69.563621  26.079104  5.106770  0.447893
# Placebo       68.084082  69.042841  20.098783  4.483167  0.393200
# Propriva      66.258529  64.957562  24.967290  4.996728  0.438242
# Ramicane      34.955595  34.848627  30.101010  5.486439  0.481193
# Stelasyn      68.438310  69.299149  27.340818  5.228845  0.458600
# Zoniferol     65.960888  65.684689  14.100301  3.755037  0.329339

# %%
value = (clean_df_csv_concat["Mouse ID"]).count()
print(value)
# Out:
# 130

# %%
drug = {
         "Drug Regimen" :
         ['Capomulin ' , 'Ceftamin' , 'Infubinol' ,"Ketapril","Naftisol","Placebo","Propriva","Ramicane","Stelasyn","Zoniferol"]}


count = (clean_df_csv_concat.groupby("Drug Regimen")["Mouse ID"]).count()
print(count)
Count = pd.DataFrame({"Count": count, 
                      #"Drug Regimen" : drug 
                      })
# Out:
# Drug Regimen
# Capomulin    21
# Ceftamin     13
# Infubinol     9
# Ketapril     11
# Naftisol     13
# Placebo      11
# Propriva      7
# Ramicane     20
# Stelasyn     11
# Zoniferol    14
# Name: Mouse ID, dtype: int64

# %%
Count.plot( y = "Count" , kind = "bar" , color = "blue" , title = "Count of mices remaining through respective treaments")
# Out:
# <Axes: title={'center': 'Count of mices remaining through respective treaments'}, xlabel='Drug Regimen'>

# %%
drug_list = ['Capomulin ' , 'Ceftamin' , 'Infubinol' ,"Ketapril","Naftisol","Placebo","Propriva","Ramicane","Stelasyn","Zoniferol"]
yy = list(count)


plt.bar(drug_list , yy , width = 0.5 ,alpha = 0.5 , align = 'center')


plt.xlabel('Drug Regimen')
plt.xticks(rotation = 90)
plt.ylabel('Count')
plt.title('Count of mices remaining through respective treaments')
plt.grid(False)
plt.show()

# %%
s = (clean_df_csv_concat.groupby("Sex")["Drug Regimen"]).count()
S = pd.DataFrame(s)
print(S)
# Out:
#         Drug Regimen
# Sex
# Female            62
# Male              68

# %%
S.plot(kind='pie', y='Drug Regimen', autopct='%1.1f%%', legend=False)
plt.axis('equal')  # Equal aspect ratio ensures that the pie chart is drawn as a circle.
plt.title('Gender Distribution of Mice')
plt.show()

# %%
gender_list = ["Female" , "Male"]


plt.pie( s, labels = gender_list, autopct='%1.1f%%')
plt.title('Gender Distribution of Mice')
plt.show()

# %%
right = pd.DataFrame(studyrepot)
right = studyrepot[studyrepot["Timepoint"] <= str(45)]

resetr = pd.DataFrame(right)
resetr = right.reset_index(drop=True)
resetr.index = resetr.index + 1 
print(right)
#print(resetr)
x=len(right)
print(x)
# Out:
# 0    Mouse ID Timepoint Tumor Volume (mm3) Metastatic Sites
# 1        b128         0                 45                0
# 2        f932         0                 45                0
# 3        g107         0                 45                0
# 4        a457         0                 45                0
# 5        c819         0                 45                0
# ...       ...       ...                ...              ...
# 1889     r944        45        41.58152074                2
# 1890     u364        45        31.02392294                3
# 1891     p438        45        61.43389223                1
# 1892     x773        45        58.63497149                4
# 1893     b879        45        72.55523894                2
#
# [1655 rows x 4 columns]
# 1655

# %%
max_time = (right.groupby("Mouse ID")["Timepoint"]).max()
drug_type =(left.groupby("Mouse ID")["Drug Regimen"]).unique()
tumor_volume = (right.groupby("Mouse ID")["Tumor Volume (mm3)"]).max()

max_time_df = pd.DataFrame(max_time)
drug_type_df = pd.DataFrame(drug_type)
tumor_volume_df = pd.DataFrame(tumor_volume)

print(tumor_volume_df)
# Out:
#          Tumor Volume (mm3)
# Mouse ID
# a203            67.97341878
# a251            65.52574285
# a262            70.71762058
# a275            62.99935619
# a366            63.44068627
# ...                     ...
# z435            48.71066147
# z578                     45
# z581            62.75445141
# z795            65.74107029
# z969            73.86784476
#
# [249 rows x 1 columns]

# %%
max_time_drug_type = pd.DataFrame()
max_time_drug_type = pd.merge(drug_type_df, max_time_df, left_on ="Mouse ID", right_on = "Mouse ID" , how='inner')
print(max_time_drug_type)
# Out:
#          Drug Regimen Timepoint
# Mouse ID
# a203      [Infubinol]        45
# a251      [Infubinol]        45
# a262        [Placebo]        45
# a275       [Ceftamin]        45
# a366       [Stelasyn]        30
# ...               ...       ...
# z435       [Propriva]        10
# z578       [Ramicane]        45
# z581      [Infubinol]        45
# z795       [Naftisol]        45
# z969       [Naftisol]        45
#
# [249 rows x 2 columns]

# %%
max_time_tumor_volume = pd.DataFrame()
max_time_tumor_volume = pd.merge(max_time_df, tumor_volume_df, left_on ="Mouse ID", right_on = "Mouse ID" , how='inner')

result = pd.DataFrame()
result = pd.merge(max_time_drug_type, max_time_tumor_volume, left_on ="Mouse ID", right_on = "Mouse ID" , how='inner')


print(result)
# Out:
#          Drug Regimen Timepoint_x Timepoint_y Tumor Volume (mm3)
# Mouse ID
# a203      [Infubinol]          45          45        67.97341878
# a251      [Infubinol]          45          45        65.52574285
# a262        [Placebo]          45          45        70.71762058
# a275       [Ceftamin]          45          45        62.99935619
# a366       [Stelasyn]          30          30        63.44068627
# ...               ...         ...         ...                ...
# z435       [Propriva]          10          10        48.71066147
# z578       [Ramicane]          45          45                 45
# z581      [Infubinol]          45          45        62.75445141
# z795       [Naftisol]          45          45        65.74107029
# z969       [Naftisol]          45          45        73.86784476
#
# [249 rows x 4 columns]

# %%
box_table = pd.DataFrame(result)
box_table = box_table.drop(columns='Timepoint_x')
box_table = box_table.drop(columns='Timepoint_y')

print(box_table)
# Out:
#          Drug Regimen Tumor Volume (mm3)
# Mouse ID
# a203      [Infubinol]        67.97341878
# a251      [Infubinol]        65.52574285
# a262        [Placebo]        70.71762058
# a275       [Ceftamin]        62.99935619
# a366       [Stelasyn]        63.44068627
# ...               ...                ...
# z435       [Propriva]        48.71066147
# z578       [Ramicane]                 45
# z581      [Infubinol]        62.75445141
# z795       [Naftisol]        65.74107029
# z969       [Naftisol]        73.86784476
#
# [249 rows x 2 columns]

# %%
box_table_capomulin = pd.DataFrame(box_table)
box_table_capomulin = box_table[box_table["Drug Regimen"] == "Capomulin"]
print(box_table_capomulin)

box_table_ramicane = pd.DataFrame(box_table)
box_table_ramicane = box_table[box_table["Drug Regimen"] == "Ramicane"]
#print(box_table_ramicane)

box_table_infubinol = pd.DataFrame(box_table)
box_table_infubinol = box_table[box_table["Drug Regimen"] == "Infubinol"]
#print(box_table_infubinol)

box_table_ceftamin = pd.DataFrame(box_table)
box_table_ceftamin = box_table[box_table["Drug Regimen"] == "Ceftamin"]
#print(box_table_ceftamin)

clean_df_csv_concat['Tumor Volume (mm3)'] = pd.to_numeric(clean_df_csv_concat['Tumor Volume (mm3)'])
# Out:
#          Drug Regimen Tumor Volume (mm3)
# Mouse ID
# b128      [Capomulin]                 45
# b742      [Capomulin]                 45
# f966      [Capomulin]                 45
# g288      [Capomulin]        46.30400254
# g316      [Capomulin]        46.80922469
# i557      [Capomulin]        47.68596303
# i738      [Capomulin]                 45
# j119      [Capomulin]        48.15820939
# j246      [Capomulin]         46.4083613
# l509      [Capomulin]        48.07045162
# l897      [Capomulin]        46.15473721
# m601      [Capomulin]                 45
# m957      [Capomulin]         46.4145177
# r157      [Capomulin]        46.53920617
# r554      [Capomulin]                 45
# r944      [Capomulin]        47.37342325
# s185      [Capomulin]                 45
# s710      [Capomulin]                 45
# t565      [Capomulin]        46.74900552
# u364      [Capomulin]        47.21219992
# v923      [Capomulin]                 45
# w150      [Capomulin]                 45
# w914      [Capomulin]                 45
# x401      [Capomulin]                 45
# y793      [Capomulin]                 45

# %%
col_list_capomulin = box_table_capomulin['Tumor Volume (mm3)'].to_numpy(dtype=float)
col_list_capomulin = np.sort(col_list_capomulin)
print(col_list_capomulin)

col_list_ramicane = box_table_ramicane['Tumor Volume (mm3)'].to_numpy(dtype=float)
col_list_ramicane = np.sort(col_list_ramicane)
print(col_list_ramicane)

col_list_infubinol = box_table_infubinol['Tumor Volume (mm3)'].to_numpy(dtype=float)
col_list_infubinol = np.sort(col_list_infubinol)
print(col_list_infubinol)

col_list_ceftamin = box_table_ceftamin['Tumor Volume (mm3)'].to_numpy(dtype=float)
col_list_ceftamin = np.sort(col_list_ceftamin)
print(col_list_ceftamin)
# Out:
# [45.         45.         45.         45.         45.         45.
#  45.         45.         45.         45.         45.         45.
#  45.         46.15473721 46.30400254 46.4083613  46.4145177  46.53920617
#  46.74900552 46.80922469 47.21219992 47.37342325 47.68596303 48.07045162
#  48.15820939]
# [45.         45.         45.         45.         45.         45.
#  45.         45.         45.         45.         45.         45.
#  45.         45.         45.         45.10742313 45.22086888 45.25253427
#  46.34383237 46.37809248 46.40908385 46.58543347 46.91089166 46.94094512
#  47.62281636]
# [45.         45.         45.         45.         50.00513807 51.54243058
#  54.04860769 54.65654872 55.62942846 55.65068132 57.03186187 58.26844248
#  60.16518046 60.91876652 60.96971133 62.11727887 62.43540402 62.75445141
#  65.52574285 66.08306589 66.19691151 67.28962147 67.68556862 67.97341878
#  72.2267309 ]
# [45.         45.         45.         45.         45.         46.78453491
#  48.72207785 52.92534846 55.74282869 56.05774909 57.91838132 59.74190064
#  59.85195552 61.38666032 61.43389223 61.84902336 62.99935619 64.19234114
#  64.29983003 64.63494887 64.72983655 67.52748237 67.74866174 68.59474498
#  68.92318457]

# %%
def cal_iqr_and_outliers(data):
    q1 = np.percentile(data, 25)
    q3 = np.percentile(data, 75)
    iqr = q3 - q1

    lower_bound = q1 - 1.5 * iqr
    print("Lower Bound:",lower_bound)
    upper_bound = q3 + 1.5 * iqr
    print("Upper Bound:",upper_bound)

    for x in data :
        if x <lower_bound or x > upper_bound:
            print(x)
            
    
    

    print("Data:", data)
    print("IQR:", iqr)
    print("Outliers:",x)
    print()

# Display IQR and outliers for each treatment group
print("Treatment Group Capomulin:")
cal_iqr_and_outliers(col_list_capomulin)

print("Treatment Group Ramicane:")
cal_iqr_and_outliers(col_list_ramicane)

print("Treatment Group Infubinol:")
cal_iqr_and_outliers(col_list_infubinol)

print("Treatment Group Ceftamin:")
cal_iqr_and_outliers(col_list_ceftamin)
# Out:
# Treatment Group Capomulin:
# Lower Bound: 42.376491720000004
# Upper Bound: 49.37251379999999
# Data: [45.         45.         45.         45.         45.         45.
#  45.         45.         45.         45.         45.         45.
#  45.         46.15473721 46.30400254 46.4083613  46.4145177  46.53920617
#  46.74900552 46.80922469 47.21219992 47.37342325 47.68596303 48.07045162
#  48.15820939]
# IQR: 1.7490055199999972
# Outliers: 48.15820939
#
# Treatment Group Ramicane:
# Lower Bound: 42.984251445
# Upper Bound: 48.359580925
# Data: [45.         45.         45.         45.         45.         45.
#  45.         45.         45.         45.         45.         45.
#  45.         45.         45.         45.10742313 45.22086888 45.25253427
#  46.34383237 46.37809248 46.40908385 46.58543347 46.91089166 46.94094512
#  47.62281636]
# IQR: 1.3438323700000012
# Outliers: 47.62281636
#
# Treatment Group Infubinol:
# Lower Bound: 36.83290494999999
# Upper Bound: 82.74144559000001
# Data: [45.         45.         45.         45.         50.00513807 51.54243058
#  54.04860769 54.65654872 55.62942846 55.65068132 57.03186187 58.26844248
#  60.16518046 60.91876652 60.96971133 62.11727887 62.43540402 62.75445141
#  65.52574285 66.08306589 66.19691151 67.28962147 67.68556862 67.97341878
#  72.2267309 ]
# IQR: 11.477135160000003
# Outliers: 72.2267309
#
# Treatment Group Ceftamin:
# Lower Bound: 25.355449580000002
# Upper Bound: 87.66645829999999
# Data: [45.         45.         45.         45.         45.         46.78453491
#  48.72207785 52.92534846 55.74282869 56.05774909 57.91838132 59.74190064
#  59.85195552 61.38666032 61.43389223 61.84902336 62.99935619 64.19234114
#  64.29983003 64.63494887 64.72983655 67.52748237 67.74866174 68.59474498
#  68.92318457]
# IQR: 15.577752179999997
# Outliers: 68.92318457

# %%
capomulin_s = pd.Series(col_list_capomulin, name='Capomulin')
ramicane_s = pd.Series(col_list_ramicane, name='Ramicane')
infubinol_s  = pd.Series(col_list_infubinol,name='Infubinol')
ceftamin_s = pd.Series(col_list_infubinol,name='Ceftamin')



df = pd.concat({'Capomulin': capomulin_s,
              'Ramicane': ramicane_s,
              'Infubinol': infubinol_s,
              'Ceftamin' : ceftamin_s,
              },axis=1)



b_plot = df.boxplot(column = ['Capomulin', 'Ramicane', 'Infubinol','Ceftamin']) 



df.boxplot(showfliers = True )

plt.title("Final Tumor Volume of Mice ")
plt.xlabel("Columns")
plt.ylabel("Values")
plt.show()

# %%
sorted_df = df_csv_concat.sort_values(by='Mouse ID')
print(sorted_df)

line_plot = pd.DataFrame(sorted_df)
line_plot = sorted_df[sorted_df["Mouse ID"] == "l509"]
print(line_plot)
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 362      a203          NaN   NaN         NaN         NaN        0.0
# 1564     a203          NaN   NaN         NaN         NaN       30.0
# 1924     a203          NaN   NaN         NaN         NaN       40.0
# 1544     a203          NaN   NaN         NaN         NaN       25.0
# 847      a203          NaN   NaN         NaN         NaN       10.0
# ...       ...          ...   ...         ...         ...        ...
# 248      z969     Naftisol  Male         9.0        30.0        NaN
# 1158     z969          NaN   NaN         NaN         NaN       15.0
# 1656     z969          NaN   NaN         NaN         NaN       30.0
# 1325     z969          NaN   NaN         NaN         NaN       20.0
# 550      z969          NaN   NaN         NaN         NaN        5.0
#
#       Tumor Volume (mm3)  Metastatic Sites
# 362            45.000000               0.0
# 1564           59.523197               1.0
# 1924           63.593490               2.0
# 1544           56.793208               1.0
# 847            51.852437               1.0
# ...                  ...               ...
# 248                  NaN               NaN
# 1158           54.713005               2.0
# 1656           65.841013               3.0
# 1325           57.898778               2.0
# 550            49.332999               0.0
#
# [2142 rows x 8 columns]
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 1395     l509          NaN   NaN         NaN         NaN       25.0
# 788      l509          NaN   NaN         NaN         NaN       10.0
# 1130     l509          NaN   NaN         NaN         NaN       15.0
# 1231     l509          NaN   NaN         NaN         NaN       20.0
# 1663     l509          NaN   NaN         NaN         NaN       30.0
# 480      l509          NaN   NaN         NaN         NaN        0.0
# 1972     l509          NaN   NaN         NaN         NaN       40.0
# 2020     l509          NaN   NaN         NaN         NaN       45.0
# 39       l509    Capomulin  Male        17.0        21.0        NaN
# 502      l509          NaN   NaN         NaN         NaN        5.0
# 1748     l509          NaN   NaN         NaN         NaN       35.0
#
#       Tumor Volume (mm3)  Metastatic Sites
# 1395           44.006257               2.0
# 788            46.759074               0.0
# 1130           47.488599               1.0
# 1231           48.070452               2.0
# 1663           44.708055               2.0
# 480            45.000000               0.0
# 1972           40.770813               2.0
# 2020           41.483008               3.0
# 39                   NaN               NaN
# 502            45.851193               0.0
# 1748           40.207288               2.0

# %%
sorted_line = line_plot.sort_values(by='Timepoint')
print(sorted_line)
sorted_line = sorted_line.iloc[0:10]
print (sorted_line)
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 480      l509          NaN   NaN         NaN         NaN        0.0
# 502      l509          NaN   NaN         NaN         NaN        5.0
# 788      l509          NaN   NaN         NaN         NaN       10.0
# 1130     l509          NaN   NaN         NaN         NaN       15.0
# 1231     l509          NaN   NaN         NaN         NaN       20.0
# 1395     l509          NaN   NaN         NaN         NaN       25.0
# 1663     l509          NaN   NaN         NaN         NaN       30.0
# 1748     l509          NaN   NaN         NaN         NaN       35.0
# 1972     l509          NaN   NaN         NaN         NaN       40.0
# 2020     l509          NaN   NaN         NaN         NaN       45.0
# 39       l509    Capomulin  Male        17.0        21.0        NaN
#
#       Tumor Volume (mm3)  Metastatic Sites
# 480            45.000000               0.0
# 502            45.851193               0.0
# 788            46.759074               0.0
# 1130           47.488599               1.0
# 1231           48.070452               2.0
# 1395           44.006257               2.0
# 1663           44.708055               2.0
# 1748           40.207288               2.0
# 1972           40.770813               2.0
# 2020           41.483008               3.0
# 39                   NaN               NaN
#      Mouse ID Drug Regimen  Sex  Age_months  Weight (g)  Timepoint  \
# 480      l509          NaN  NaN         NaN         NaN        0.0
# 502      l509          NaN  NaN         NaN         NaN        5.0
# 788      l509          NaN  NaN         NaN         NaN       10.0
# 1130     l509          NaN  NaN         NaN         NaN       15.0
# 1231     l509          NaN  NaN         NaN         NaN       20.0
# 1395     l509          NaN  NaN         NaN         NaN       25.0
# 1663     l509          NaN  NaN         NaN         NaN       30.0
# 1748     l509          NaN  NaN         NaN         NaN       35.0
# 1972     l509          NaN  NaN         NaN         NaN       40.0
# 2020     l509          NaN  NaN         NaN         NaN       45.0
#
#       Tumor Volume (mm3)  Metastatic Sites
# 480            45.000000               0.0
# 502            45.851193               0.0
# 788            46.759074               0.0
# 1130           47.488599               1.0
# 1231           48.070452               2.0
# 1395           44.006257               2.0
# 1663           44.708055               2.0
# 1748           40.207288               2.0
# 1972           40.770813               2.0
# 2020           41.483008               3.0

# %%
plt.plot(sorted_line["Timepoint"], sorted_line["Tumor Volume (mm3)"])
plt.xlabel('Timepoint')  
plt.ylabel('Tumor Volume (mm3)')  
plt.title('Tumor Volume of one mouse against Time')  
plt.xlim(0, max(sorted_line['Timepoint']+5))
plt.ylim(40, max(sorted_line['Tumor Volume (mm3)']+5))
plt.grid(True)  
plt.show()

# %%
mouse_weight = (left.groupby("Mouse ID")["Weight (g)"]).unique()
scatterp = pd.merge(mouse_weight , df_csv_concat , left_on ="Mouse ID", right_on = "Mouse ID" , how='outer')
print(scatterp)
# Out:
#      Mouse ID Weight (g)_x Drug Regimen     Sex  Age_months  Weight (g)_y  \
# 0        a203         [23]    Infubinol  Female        20.0          23.0
# 1        a203         [23]          NaN     NaN         NaN           NaN
# 2        a203         [23]          NaN     NaN         NaN           NaN
# 3        a203         [23]          NaN     NaN         NaN           NaN
# 4        a203         [23]          NaN     NaN         NaN           NaN
# ...       ...          ...          ...     ...         ...           ...
# 2137     z969         [30]          NaN     NaN         NaN           NaN
# 2138     z969         [30]          NaN     NaN         NaN           NaN
# 2139     z969         [30]          NaN     NaN         NaN           NaN
# 2140     z969         [30]          NaN     NaN         NaN           NaN
# 2141     z969         [30]          NaN     NaN         NaN           NaN
#
#       Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 0           NaN                 NaN               NaN
# 1           0.0           45.000000               0.0
# 2           5.0           48.508468               0.0
# 3          10.0           51.852437               1.0
# 4          15.0           52.777870               1.0
# ...         ...                 ...               ...
# 2137       25.0           63.145652               2.0
# 2138       30.0           65.841013               3.0
# 2139       35.0           69.176246               4.0
# 2140       40.0           70.314904               4.0
# 2141       45.0           73.867845               4.0
#
# [2142 rows x 9 columns]

# %%
plt.scatter(scatterp['Weight (g)_x'], scatterp['Tumor Volume (mm3)'])
plt.xlabel('Weight(g)')
plt.ylabel('Tumor Volume (mm3)')
plt.title('Tumor Volume against Weight')
plt.show()

scatterp['Tumor Volume (mm3)'] = pd.to_numeric(scatterp['Tumor Volume (mm3)'])

# %%
selected_columns = ['Weight (g)_x', 'Tumor Volume (mm3)']
cox = scatterp[selected_columns].corr()
correalation = cox["Tumor Volume (mm3)"].tolist()
print("The correlation coefficient is :" ,correalation[0])
corrrr = correalation[0]
print(corrrr)
# Out:
# The correlation coefficient is : 0.5874984592659983
# 0.5874984592659983

# %%
x1 = pd.DataFrame(scatterp)
x1 = scatterp['Weight (g)_x'].to_numpy(dtype=int)
print(x1)
# Out:
# [23 23 23 ... 30 30 30]

# %%
y = scatterp['Tumor Volume (mm3)'].to_numpy(dtype=int)

slope, intercept, r_value, p_value, std_err = stats.linregress(x1 , y)

# %%
m = np.polyfit(x1, y,1)
print(m)

regression_line = np.poly1d(corrrr)

#print(regression_line)

plt.scatter(x1, y)

plt.plot(x1, intercept + slope * x1, 'r', label='Regression Line')

plt.xlabel('Weight(g)')
plt.ylabel('Tumor Volume (mm3)')
plt.title('Tumor Volume against Weight')
plt.show()
# Out:
# [ -6595166.83200363 -80041248.47365852]
